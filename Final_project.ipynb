# %%
import pandas as pd

# %%
compare = pd.read_csv('/Users/lanbao/Downloads/Final_Project/Price_rent_comparison.csv')
compare.head()
# Out:
#           Country  iphone_price  avg_rent  rent_fraction
# 0             USA          1532  1224.370          0.344
# 1  United Kingdom          1910   919.825          0.289
# 2         Germany          1962   791.840          0.278
# 3           China          1820   405.700          0.262

# %%
compare.plot()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#Create combo chart
fig, ax1 = plt.subplots(figsize=(10,6))
color = 'tab:green'
#bar plot creation
ax1.set_title('iPhone price and rent price comparison', fontsize=16)
ax1.set_xlabel('Country', fontsize=16)
ax1.set_ylabel('USD', fontsize=16)
ax1 = sns.barplot(x='Country', y='iphone_price', data = compare, palette='summer')
#ax1.tick_params(axis='y')
#specify we want to share the same x-axis
ax2 = ax1.twinx()
color = 'tab:red'
#line plot creation
#ax2.set_ylabel('Avg Percipitation %', fontsize=16)
ax2 = sns.lineplot(x='Country', y='avg_rent', data = compare, sort=False, color=color)
#ax2.tick_params(axis='y', color=color)
#show plot
plt.show()

# %%
#import plotly.express as px

#fig = px.line(data_frame=compare, x='Country', y='avg_rent',
#             labels=dict(x="Country", y="USD"))
#fig.add_bar(x='Country', y='iphone_price')
#fig.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-3c5df485aad4> in <module>
# ----> 1 import plotly.express as px
#       2
#       3 fig = px.line(data_frame=compare, x='Country', y='avg_rent',
#       4              labels=dict(x="Country", y="USD"))
#       5 fig.add_bar(x='Country', y='iphone_price')
#
# ModuleNotFoundError: No module named 'plotly'

# %%
sales = pd.read_csv('/Users/lanbao/Downloads/Final_Project/iphone_sales.csv')
sales.head()
# Out:
#       Date   Asia     EU     UK    USA
# 0  2016-01  11.01  28.26  44.64  52.90
# 1  2016-02  10.86  27.80  44.47  53.37
# 2  2016-03  10.99  26.86  43.50  52.16
# 3  2016-04  11.19  26.55  42.89  52.42
# 4  2016-05  11.30  26.84  43.39  52.78

# %%
sales.plot()

# %%
rev_plot = sales.plot.line(title="Sales percent in 4 regions from 2016-2020") 
#set other variable name so that if change happen, it won't affect older code
rev_plot.set_xlabel('%')
rev_plot.set_ylabel('Month')
plt.show()
